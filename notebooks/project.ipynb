# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
path_custumer = '../data/olis/olist_customers_dataset.csv'
path_orders = '../data/olis/olist_orders_dataset.csv'
path_payment = '../data/olis/olist_order_payments_dataset.csv'
path_item = '../data/olis/olist_order_items_dataset.csv'
path_product = '../data/olis/olist_products_dataset.csv'
path_seller = '../data/olis/olist_sellers_dataset.csv'

# %%
custumer = pd.read_csv(path_custumer)
orders = pd.read_csv(path_orders)
payment = pd.read_csv(path_payment)
item = pd.read_csv(path_item)
product = pd.read_csv(path_product)
seller = pd.read_csv(path_seller)

# %%
item['shipping_limit_date'] = pd.to_datetime(item['shipping_limit_date'])
date_col = ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']
for col in date_col:
    orders[col] = pd.to_datetime(orders[col])

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
custumer
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
payment.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
item.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# ...

# %%
item['shipping_limit_date'].dt.date.value_counts().sort_index().plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
product.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
seller.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
merged_data = (orders
         .merge(item, on='order_id')
         .merge(payment, on='order_id')
         .merge(product, on='product_id')
         .merge(custumer, how='left', on='customer_id'))

# %%
merged_data
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 4       0e7e841ddf8f8f2de2bad69267ecfbcf  26c7ac168e1433912a51b924fbd34d34
# ...                                  ...                               ...
# 117596  e8fd20068b9f7e6ec07068bb7537f781  609b9fb8cad4fe0c7b376f77c8ab76ad
# 117597  e8fd20068b9f7e6ec07068bb7537f781  609b9fb8cad4fe0c7b376f77c8ab76ad
# 117598  cfa78b997e329a5295b4ee6972c02979  a2f7428f0cafbc8e59f20e1444b67315
# 117599  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 117600  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
delta_time = (merged_data
              .groupby('customer_unique_id')[['order_purchase_timestamp']]
              .apply(lambda x: x.max() - x.min()))

# %%
max_date = merged_data['order_purchase_timestamp'].max()
delta_left = (merged_data
              .groupby('customer_unique_id')[['order_purchase_timestamp']]
              .apply(lambda x: max_date - x.max()))

# %%
f, ax = plt.subplots()
delta_left['order_purchase_timestamp'].dt.days.hist(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(merged_data['customer_unique_id'].value_counts().to_numpy())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = pd.read_csv('../data/Final Project Dataset.csv')

# %%
df
# Out:
#         Factura       Fecha Customer_ID     Sexo Venta ($)  \
# 0      227837.0   23/8/2019      175335  #ERROR!    2.901
# 1      227832.0   23/8/2019      140862  #ERROR!    7.256
# 2      227831.0   23/8/2019      225831  #ERROR!    2.901
# 3      227826.0   23/8/2019      185845  #ERROR!    4.462
# 4      227823.0   23/8/2019      153566  #ERROR!    2.901
# ...         ...         ...         ...      ...       ...
# 65003       0.0   9/10/2018      178170  #ERROR!      -
# 65004       0.0  12/10/2018      153407  #ERROR!      -
# 65005       0.0  17/10/2018      113388  #ERROR!      -
# 65006       0.0  20/10/2018      139037  #ERROR!      -
# 65007       0.0  23/10/2018      177010  #ERROR!      -
#
#                      Ciudad  Product ID
# 0                    Rivera           4
# 1      Montevideo Periferia          19
# 2                   Durazno           4
# 3      Montevideo Periferia           0
# 4                    Rivera           4
# ...

# %%
plt.figure()
plt.plot(df['Customer_ID'].value_counts().to_numpy())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# - Recency: time between initial purchase and most recent (last) purchase
# - Frequency: number of repeat purchases made by a customer (total purchases — 1)
# - Monetary: total spent on purchases
# - Place:
# - Sex
# -
